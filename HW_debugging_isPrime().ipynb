# %% [markdown]
# <a href="https://colab.research.google.com/github/ssmb89/Classes/blob/main/HW_debugging_isPrime().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Debug isPrime()
# What is your preferred method? Do you like using print() or prefer *pdb*?   Since mistakes in programs will happen, the important part is that you have a debugging strategy, not which tool you use.
#
# Here is a function that needs debugging. Using either print() or *pdb*, debug the following function.

# %%
def isPrime(candidate):
    if candidate <= 1:
        return False

    lower = candidate - 1
    breakpoint()
    while lower > 1:
        if candidate / lower == candidate // lower:
            return False
        lower -= 1

    return True

# %%
isPrime(12)
# Out:
# > <ipython-input-5-07e5e274e837>(7)isPrime()
# -> while lower > 1:
# (Pdb) lower
# 11
# (Pdb) candidate
# 12
# (Pdb) n
# > <ipython-input-5-07e5e274e837>(8)isPrime()
# -> if candidate / lower == candidate // lower:
# (Pdb) n
# > <ipython-input-5-07e5e274e837>(10)isPrime()
# -> lower -= 1
# (Pdb) lower
# 11
# (Pdb) n
# > <ipython-input-5-07e5e274e837>(7)isPrime()
# -> while lower > 1:
# (Pdb) n
# > <ipython-input-5-07e5e274e837>(8)isPrime()
# -> if candidate / lower == candidate // lower:
# (Pdb) n
# > <ipython-input-5-07e5e274e837>(10)isPrime()
# -> lower -= 1
# (Pdb) r
# --Return--
# > <ipython-input-5-07e5e274e837>(9)isPrime()->False
# -> return False
# --KeyboardInterrupt--
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-6-242577e523ed> in <module>()
# ----> 1 isPrime(12)
#
# <ipython-input-5-07e5e274e837> in isPrime(candidate)
#       7     while lower > 1:
#       8         if candidate / lower == candidate // lower:
# ----> 9             return False
#      10         lower -= 1
#      11
#
# /usr/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# /usr/lib/python3.7/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
#     155             # The user issued a 'next' or 'until' command.
#     156             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:

# %%
def isPrime(candidate):
    if candidate <= 1:
        return False

    breakpoint()
    lower = candidate - 1
    while lower > 1:
        if candidate / lower == candidate // lower:
            return False
        lower -= 1

    return True

# %%
isPrime(13)
# Out:
# > <ipython-input-7-b54338a879b8>(6)isPrime()
# -> lower = candidate - 1
# (Pdb) candidate
# 13
# (Pdb) n
# > <ipython-input-7-b54338a879b8>(7)isPrime()
# -> while lower > 1:
# (Pdb) lower
# 12
# (Pdb) n
# > <ipython-input-7-b54338a879b8>(8)isPrime()
# -> if candidate / lower == candidate // lower:
# (Pdb) lower
# 12
# (Pdb) n
# > <ipython-input-7-b54338a879b8>(10)isPrime()
# -> lower -= 1
# (Pdb) lower
# 12
# (Pdb) n
# > <ipython-input-7-b54338a879b8>(7)isPrime()
# -> while lower > 1:
# (Pdb) m
# *** NameError: name 'm' is not defined
# (Pdb) n
# > <ipython-input-7-b54338a879b8>(8)isPrime()
# -> if candidate / lower == candidate // lower:
# (Pdb) r
# --Return--
# > <ipython-input-7-b54338a879b8>(12)isPrime()->True
# -> return True
# (Pdb) exot
# *** NameError: name 'exot' is not defined
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-8-d644da896601> in <module>()
# ----> 1 isPrime(13)
#
# <ipython-input-7-b54338a879b8> in isPrime(candidate)
#      10         lower -= 1
#      11
# ---> 12     return True
#
# /usr/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
#      94             return self.dispatch_exception(frame, arg)
#
# /usr/lib/python3.7/bdb.py in dispatch_return(self, frame, arg)
#     152             finally:
#     153                 self.frame_returning = None
# --> 154             if self.quitting: raise BdbQuit
#     155             # The user issued a 'next' or 'until' command.
#     156             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:
